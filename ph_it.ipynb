# %%
import os

files = [f for f in os.listdir(os.path.abspath('')) if f.endswith('.txt')]

for file in files:
    with open(file, 'r') as f:
        print(file)
        contents = f.readlines()
        print(contents[0:2])
# Out:
# HH-001_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD RESPONDENTS\n', 'Households\n']
# HH-002_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH AND WITHOUT ELECTRICITY\n']
# HH-003_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH AND WITHOUT RADIO\n']
# HH-004_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH AND WITHOUT TELEVISION\n']
# HH-005_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'BY TYPE AND WITH TELEVISION\n']
# HH-006_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH TELEVISION BY TYPE OF TELEVISION SERVICE\n']
# HH-006_2.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH TELEVISION BY TYPE OF TELEVISION SERVICE\n']
# HH-007_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH AND WITHOUT FIXED TELEPHONE LINE\n']
# HH-008_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH AND WITHOUT CELLPHONE\n']
# HH-010_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH A COMPUTER BY TYPE\n']
# HH-010_2.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH A COMPUTER BY TYPE\n']
# HH-011_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'BY ALTERNATIVE MEANS TO ACCESS COMPUTERS\n']
# HH-011_2.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'BY ALTERNATIVE MEANS TO ACCESS COMPUTERS\n']
# HH-012_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'WITH AND WITHOUT INTERNET ACCESS\n']
# HH-013_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'BY TYPE OF INTERNET CONNECTION\n']
# HH-013_2.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'BY TYPE OF INTERNET CONNECTION\n']
# HH-014_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD RESPONDENTS\n', 'BY USE OF INTERNET ACCESS\n']
# HH-014_2.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'BY USE OF INTERNET ACCESS\n']
# HH-015_1.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD\n', 'BY REASON FOR NOT HAVING INTERNET ACCESS\n']
# HH-015_2.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD RESPONDENTS\n', 'BY REASON FOR NOT HAVING INTERNET ACCESS\n']
# HH-015_3.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD RESPONDENTS\n', 'BY REASON FOR NOT HAVING INTERNET ACCESS\n']
# HH-015_4.txt
# ['REGIONAL DISTRIBUTION OF HOUSEHOLD RESPONDENTS\n', 'BY REASON FOR NOT HAVING INTERNET ACCESS\n']
# IND-003_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY AGE GROUP\n']
# IND-003_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY AGE GROUP\n']
# IND-004_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY EDUCATIONAL ATTAINMENT\n']
# IND-004_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY EDUCATIONAL ATTAINMENT\n']
# IND-004_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY EDUCATIONAL ATTAINMENT\n']
# IND-005_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY LABOR FORCE STATUS\n']
# IND-005_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY LABOR FORCE STATUS\n']
# IND-005_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'BY LABOR FORCE STATUS\n']
# IND-012_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WHO ARE USING/NOT USING ANTIVIRUS SOFTWARE\n']
# IND-015_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING INTERNET BY LOCATION\n']
# IND-015_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING INTERNET BY LOCATION\n']
# IND-015_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING INTENRET BY LOCATION\n']
# IND-017_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING INTERNET BY ACTIVITY\n']
# IND-017_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING INTERNET BY ACTIVITY\n']
# IND-017_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING INTERNET BY ACTIVITY\n']
# IND-047_1.txt
# ['INDIVIDUALS USING/NOT USING THE INTERNET\n', 'Using the Internet Not Using the Internet\n']
# IND_001_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUAL RESPONDENTS\n', 'NCR 6,692,443 14.9%\n']
# IND_002_1.txt
# ['REGIONAL DISTRIBUTION OF\n', 'INDIVIDUAL RESPONDENTS BY SEX\n']
# IND_006_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WATCHING AND NOT WATCHING TV\n']
# IND_007_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING/NOT USING CELLPHONE\n']
# IND_008_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING/NOT USING A COMPUTER\n']
# IND_009_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING A COMPUTER BY TYPE OF COMPUTER\n']
# IND_009_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING A COMPUTER BY TYPE OF COMPUTER\n']
# IND_010_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING A COMPUTER BY ACTIVITY\n']
# IND_010_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING A COMPUTER BY ACTIVITY\n']
# IND_010_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING A COMPUTER BY ACTIVITY\n']
# IND_010_4.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING A COMPUTER BY ACTIVITY\n']
# IND_010_5.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING A COMPUTER BY ACTIVITY\n']
# IND_012_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING/NOT USING INTERNET\n']
# IND_013_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'USING INTERNET BY TYPE OF DEVICE\n']
# IND_013_2.txt
# ['REGIONAL DISTIRBUTION OF INDIVIDUALS\n', 'USING INTERNET BY TYPE OF DEVICE\n']
# IND_014_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT USING INTERNET BY REASON\n']
# IND_014_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT USING INTERNET BY REASON\n']
# IND_014_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT USING INTERNET BY REASON\n']
# IND_018_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING/ NOT RECOMMENDING INTERNET CONNECTION\n']
# IND_019_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING THE INTERNET BY REASON\n']
# IND_019_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING THE INTERNET BY REASON\n']
# IND_020_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'ACCESSING/ NOT ACCESSING GOVERNMENT WEBSITES\n']
# IND_022_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'ACCESSING GOVERNMENT WEBSITES BY TYPE OF SERVICE\n']
# IND_022_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'ACCESSING GOVERNMENT WEBSITES BY TYPE OF SERVICE\n']
# IND_022_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'ACCESSING GOVERNMENT WEBSITES BY TYPE OF SERVICE\n']
# IND_022_4.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'ACCESSING GOVERNMENT WEBSITES BY TYPE OF SERVICE\n']
# IND_022_5.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'ACCESSING GOVERNMENT WEBSITES BY TYPE OF SERVICE\n']
# IND_023_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING/ NOT RECOMMENDING TO ACCESS GOVERNMENT WEBSITES\n']
# IND_024_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING TO ACCESS GOVERNMENT WEBSITES BY REASON\n']
# IND_024_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING TO ACCESS GOVERNMENT WEBSITES BY REASON\n']
# IND_025_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT RECOMMENDING TO ACCESS GOVERNMENT WEBSITES BY REASON\n']
# IND_025_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT RECOMMENDING TO ACCESS GOVERNMENT WEBSITES BY REASON\n']
# IND_026_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'AWARE/UNAWARE OF PERFORMING BUSINESS TRANSACTIONS ONLINE\n']
# IND_027_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WITH/WITHOUT ELECTRONIC BANK ACCOUNT\n']
# IND_029_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WITH/WITHOUT ONLINE SELLING OR BUYING ACCOUNT\n']
# IND_031_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'SELLING GOODS AND SERVICES ONLINE BY PLATFORM\n']
# IND_031_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'SELLING GOODS AND SERVICES ONLINE BY PLATFORM\n']
# IND_032_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING/ NOT RECOMMENDING TO SELL GOODS & SERVICES ONLINE\n']
# IND_033_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING TO SELL GOODS AND SERVICES ONLINE BY REASON\n']
# IND_033_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'RECOMMENDING TO SELL GOODS AND SERVICES ONLINE BY REASON\n']
# IND_035_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'PURCHASING GOODS AND SERVICES ONLINE BY SITE/MOBILE APPLICATION\n']
# IND_035_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'PURCHASING GOODS AND SERVICES ONLINE BY SITE/MOBILE APPLICATION\n']
# IND_036_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'PURCHASING GOODS AND SERVICES ONLINE BY DEVICE USED\n']
# IND_037_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'PURCHASING GOODS AND SERVICES ONLINE, BY MODE OF DELIVERY\n']
# IND_037_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'PURCHASING GOODS AND SERVICES ONLINE, BY MODE OF DELIVERY\n']
# IND_038_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'PURCHASING GOODS AND SERVICES ONLINE BY TYPE OF PAYMENT\n']
# IND_038_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'PURCHASING GOODS AND SERVICES ONLINE BY TYPE OF PAYMENT\n']
# IND_039_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS PURCHASING GOODS AND\n', 'SERVICES ONLINE, BY TYPE OF GOODS AND SERVICES\n']
# IND_039_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS PURCHASING GOODS AND\n', 'SERVICES ONLINE, BY TYPE OF GOODS AND SERVICES\n']
# IND_039_3.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS PURCHASING GOODS AND\n', 'SERVICES ONLINE, BY TYPE OF GOODS AND SERVICES\n']
# IND_039_4.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS PURCHASING GOODS AND\n', 'SERVICES ONLINE, BY TYPE OF GOODS AND SERVICES\n']
# IND_039_5.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS PURCHASING GOODS AND\n', 'SERVICES ONLINE, BY TYPE OF GOODS AND SERVICES\n']
# IND_040_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT PURCHASING GOODS AND SERVICES ONLINE BY REASON\n']
# IND_040_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT PURCHASING GOODS AND SERVICES ONLINE BY REASON\n']
# IND_041_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT USING ELECTRONIC PAYMENTS FOR ONLINE PURCHASES BY REASON\n']
# IND_041_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'NOT USING ELECTRONIC PAYMENTS FOR ONLINE PURCHASES BY REASON\n']
# IND_042_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WHO HAVE BEEN A VICTIM OF CYBER SCAM INCIDENTS BY INCIDENTS\n']
# IND_042_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WHO HAVE BEEN A VICTIM OF CYBER SCAM INCIDENTS BY INCIDENTS\n']
# IND_043_1.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WHO HAVE REPORTED THE INCIDENTS BY AUTHORITY\n']
# IND_043_2.txt
# ['REGIONAL DISTRIBUTION OF INDIVIDUALS\n', 'WHO HAVE REPORTED THE INCIDENTS BY AUTHORITY\n']
# IND_044_1.txt
# ['REGIONAL DISTRIBUTION OF CYBER SCAM VICTIMS\n', 'WHO HAVE REPORTED THE INCIDENTS BY AUTHORITY\n']
# IND_044_2.txt
# ['REGIONAL DISTRIBUTION OF CYBER SCAM VICTIMS\n', 'WHO HAVE REPORTED THE INCIDENTS BY AUTHORITY\n']
# IND_045_1.txt
# ['REGIONAL DISTIRBUTION OF INDIVIDUALS AWARE/NOT AWARE OF\n', 'CYBERSECURITY/DATA PRIVACY\n']
# IND_047_1.txt
# ['INDIVIDUALS USING/NOT USING THE INTERNET\n', 'Using the Internet Not Using the Internet\n']
# IND_048_1.txt
# ['INDIVIDUALS USING/NOT USING CELLPHONE\n', 'Not Using the Cellphone OF hate Bada (-MOz-HA ol ates at\n']
# IND_049_1.txt
# ['INDIVIDUALS USING/NOT USING COMPUTER\n', 'Not Using the Computer Using the Computer\n']
# IND_050_1.txt
# ['INDIVIDUALS ACCESSING/NOT ACCESSING\n', "Not Accessing Gov't Websites Accessing Gov't Websites\n"]
# IND_051_1.txt
# ['INDIVIDUALS WITH/WITHOUT\n', 'Without Online Bank Account With Online Bank Account\n']
# IND_053_1.txt
# ['INDIVIDUALS SELLING/NOT SELLING GOODS AND SERVICES\n', 'Not Selling gooes ee eee Pee eleccdsendiseariees Online\n']
# IND_055_1.txt
# ['INDIVIDUALS WHO HAVE BEEN A VICTIM OF CYBERSCAM\n', 'BY SEX AND INCIDENT\n']

# %% [markdown]
# #### Relevant for viz (data from DICT)
#
# * HH-012_1.txt - Regional Distribution of Households With and Without Internet Access
# * HH-004_1.txt - Regional Distribution of Households With and Without Television

# %%
import pandas as pd

data = pd.read_csv('HH-012_1.txt', delimiter='\t', skiprows=2)
data.head()
# Out:
#        With Internet Access Without Internet Access
# 0       NCR 1,000,671 33.2 2,008,874 66.8 3,009,545
# 1             CAR 115,495 29.8 272,693 70.2 388,188
# 2     REGION! 224,947 18.0 1,025,390 82.0 1,250,337
# 3       REGION II 154,330 18.0 701,564 82.0 855,893
# 4  REGION III 663,095 23.5 2,160,105 76.5 2,823,200

# %%
data_tv = pd.read_csv('HH-004_1.txt', delimiter='\t', skiprows=2)
data_tv.head()
# Out:
#                 With Television Without Television
# 0         NCR 2,829,350 94.0 180,195 6.0 3,009,545
# 1             CAR 315,885 81.4 72,303 18.6 388,188
# 2   REGION I 1,090,157 87.2 160,180 12.8 1,250,337
# 3      REGION II 713,038 83.3 142,855 16.7 855,893
# 4  REGION III 2,668,170 94.5 155,029 5.5 2,823,200

# %%
df_clean=pd.DataFrame(columns=['Region','With Internet', 'Without Internet', 'Total'])

# data to clean df
df_clean['Total'] = data[data.columns[0]].apply(lambda x:x.split()[-1])
df_clean['Without Internet'] = data[data.columns[0]].apply(lambda x: x.split()[-3])
df_clean['With Internet'] = data[data.columns[0]].apply(lambda x: x.split()[-5])
df_clean['Region'] = data[data.columns[0]].apply(lambda x: x.split()[:-5])
df_clean['Region'] = df_clean['Region'].apply(lambda x: ' '.join(x))
df_clean['Region'][2] = 'REGION I'

df_clean['With Internet'][6] = 52140

# %%
# TV data to clean df
df_clean.insert(3, 'With television', data_tv[data_tv.columns[0]].apply(lambda x: x.split()[-5]))
df_clean.insert(4, 'Without television', data_tv[data_tv.columns[0]].apply(lambda x: x.split()[-3]))

df_clean['With television'][6] = 501164
df_clean['With television'][11] = 514945

# %%
# remove commas and convert to numeric values
df_clean.replace(',', '', regex=True, inplace=True)
cols_to_conv = df_clean.columns[1:]

for col in cols_to_conv:
    df_clean[col] = pd.to_numeric(df_clean[col]).astype('int32')
    
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              17 non-null     object
#  1   With Internet       17 non-null     int32
#  2   Without Internet    17 non-null     int32
#  3   With television     17 non-null     int32
#  4   Without television  17 non-null     int32
#  5   Total               17 non-null     int32
# dtypes: int32(5), object(1)
# memory usage: 604.0+ bytes

# %%
hh_with = df_clean['With Internet'].sum()
hh_without = df_clean['Without Internet'].sum()
hh_total = hh_with + hh_without

print('national ICT Household Survey 2019')
print('Households With Access to Internet: ', hh_with)
print('Households Without Access to Internet: ', hh_without)
print('Households Surveyed: ', hh_total)

print(f'No access to Internet: {100 * hh_without / hh_total:.2f}%')
# Out:
# national ICT Household Survey 2019
# Households With Access to Internet:  4123882
# Households Without Access to Internet:  19236479
# Households Surveyed:  23360361
# No access to Internet: 82.35%

# %%
with_tv = df_clean['With television'].sum()
without_tv = df_clean['Without television'].sum()
tv_total = with_tv + without_tv

print('Households with TV: ', with_tv)
print('Households without TV: ', without_tv)
print('Households Surveyed: ', tv_total)

print(f'No access to television: {100 * without_tv / tv_total:.2f}%')
# Out:
# Households with TV:  19330082
# Households without TV:  4030879
# Households Surveyed:  23360961
# No access to television: 17.25%

# %%
df_clean.drop(columns=['Total'], inplace=True)
df_clean
# Out:
#          Region  With Internet  Without Internet  With television  \
# 0           NCR        1000671           2008874          2829350
# 1           CAR         115495            272693           315885
# 2      REGION I         224947           1025390          1090157
# 3     REGION II         154330            701564           713038
# 4    REGION III         663095           2160105          2668170
# 5   REGION IV-A         844147           2642039          3217334
# 6   REGION IV-B          52140            634776           501164
# 7      REGION V          75063            955923           774635
# 8     REGION VI         177260           1528295          1388172
# 9    REGION VII         186621           1633431          1326302
# 10  REGION VIII         173539            869184           732218
# 11    REGION IX          46424            697312           514945
# 12     REGION X          68753            989706           799017
# 13    REGION XI         163277           1109807          1019529
# 14   REGION XII         108209            955030           742182
# 15       CARAGA          46331            555181           450545
# 16        BARMM          23580            497169           247439
#
#     Without television
# 0               180195
# 1                72303
# 2               160180
# 3               142855
# 4               155029
# 5               268852
# 6               185752
# 7               256351
# 8               317384
# 9               493750
# 10              310506
# 11              228790
# 12              259442
# 13              253556
# 14              321057
# 15              150967
# 16              273910

# %%
df_clean.to_excel('net_v_tv.xlsx', index=False)
